# %% [markdown]
# <a href="https://colab.research.google.com/github/wangyuchiao/vocabuddy-group-5/blob/main/VocaBuddy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vocab = {
    "collaboration": "協作",
    "repository": "儲存庫",
    "commit": "提交",
}

for en, zh in vocab.items():
    print(f"{en}：{zh}")
# Out:
# collaboration：協作
# repository：儲存庫
# commit：提交
